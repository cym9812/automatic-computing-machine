# %%
import pandas as pd
import numpy as np
import os
# Import the data using the file path
data = pd.read_csv("Machine_Learning/ML501/week2/data/Orange_Telecom_Churn_Data.csv")
#data = pd.read_csv("Orange_Telecom_Churn_Data.csv")

# %% [markdown]
# 创建
# ====

# %%
pd.DataFrame(np.arange(20).reshape(4,5),index = list("ABCD"),columns=list('vwxyz'))
# Out:
#     v   w   x   y   z
# A   0   1   2   3   4
# B   5   6   7   8   9
# C  10  11  12  13  14
# D  15  16  17  18  19

# %%
pd.date_range('20180101', periods=5) #创建时间序列
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# pd.read_table(filename) 从限定分隔符的文本文件导入数据
#
# pd.read_excel(filename) 从Excel文件导入数据
#
# pd.read_sql(query, connection_object) 从SQL表/库导入数据
#
# pd.read_json(json_string) 从JSON格式的字符串导入数据
#
# pd.read_html(url) 解析URL、字符串或者HTML文件，抽取其中的tables表格
#
# pd.read_clipboard() 从你的粘贴板获取内容，并传给read_table()
#
# pd.DataFrame(dict) 从字典对象导入数据，Key是列名，Value是数据

# %% [markdown]
# 查看
# ====

# %%
data.head(5)
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 0    KS             128        415     382-4657        no             yes
# 1    OH             107        415     371-7191        no             yes
# 2    NJ             137        415     358-1921        no              no
# 3    OH              84        408     375-9999       yes              no
# 4    OK              75        415     330-6626       yes              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# ...

# %%
data.tail(5)
# Out:
#      state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 4995    HI              50        408     365-8751        no             yes
# 4996    WV             152        415     334-9736        no              no
# 4997    DC              61        415     333-6861        no              no
# 4998    DC             109        510     394-2206        no              no
# 4999    VT              86        415     373-8058        no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 4995                     40              235.7              127
# 4996                      0              184.2               90
# 4997                      0              140.6               89
# 4998                      0              188.8               67
# 4999                     34              129.4              102
#
#       total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
data.dtypes #查看每列数据类型
# Out:
# state                             object
# account_length                     int64
# area_code                          int64
# phone_number                      object
# intl_plan                         object
# voice_mail_plan                   object
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes               float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churned                             bool
# dtype: object

# %%
data.columns
# Out:
# Index(['state', 'account_length', 'phone_number', 'intl_plan',
#        'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes',
#        'total_day_calls', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
#        'total_night_calls', 'total_night_charge', 'total_intl_minutes',
#        'total_intl_calls', 'churned'],
#       dtype='object')

# %%
data.sort_values(by='account_length', ascending=False).head() #按值排序
# Out:
#      state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 817     UT             243        510     355-9360        no              no
# 4260    WA             238        415     351-4104        no              no
# 4395    IL             233        408     390-2383        no              no
# 4389    HI             232        415     364-3035        no              no
# 1408    NM             232        408     386-9177        no              no
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 817                       0               95.5               92
# 4260                      0              202.0               60
# 4395                      0              137.3               94
# 4389                      0              248.2              128
# 1408                      0              165.6              104
#
#       total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
data['state'].head()  #选择表格中的'state'列，使用类字典属性,返回的是Series类型
# Out:
# 0    KS
# 1    OH
# 2    NJ
# 3    OH
# 4    OK
# Name: state, dtype: object

# %%
data.state.head()    #选择表格中的'state'列，使用点属性,返回的是Series类型
# Out:
# 0    KS
# 1    OH
# 2    NJ
# 3    OH
# 4    OK
# Name: state, dtype: object

# %%
data[['state']].head()  #选择表格中的'state'列，返回的是DataFrame属性
# Out:
#   state
# 0    KS
# 1    OH
# 2    NJ
# 3    OH
# 4    OK

# %%
data[['state','total_day_minutes']].head()  #选择表格中的'state'、'total_day_minutes'列
# Out:
#   state  total_day_minutes
# 0    KS              265.1
# 1    OH              161.6
# 2    NJ              243.4
# 3    OH              299.4
# 4    OK              166.7

# %%
data[0:2]  #返回第1行到第2行的所有行，前闭后开，包括前不包括后
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 0    KS             128        415     382-4657        no             yes
# 1    OH             107        415     371-7191        no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                10.0                 3                2.7
# ...

# %%
data[1:2]  #返回第2行，从0计，返回的是单行，通过有前后值的索引形式，
       #如果采用data[1]则报错
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 1    OH             107        415     371-7191        no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 1                     26              161.6              123
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 1             27.47  ...              103             16.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 1                254.4                103               11.45
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 1                13.7                 3                3.7
#
#    number_customer_service_calls  churned
# 1                              1    False
#
# [1 rows x 21 columns]

# %%
data.iloc[1:2] #返回第2行的第三种方法，返回的是DataFrame，跟data[1:2]同
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 1    OH             107        415     371-7191        no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 1                     26              161.6              123
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 1             27.47  ...              103             16.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 1                254.4                103               11.45
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 1                13.7                 3                3.7
#
#    number_customer_service_calls  churned
# 1                              1    False
#
# [1 rows x 21 columns]

# %%
data.iloc[:,1:3].head()   #数据切片操作，切连续的数据块
# Out:
#    account_length  area_code
# 0             128        415
# 1             107        415
# 2             137        415
# 3              84        408
# 4              75        415

# %%
data.iloc[[0,2,3],[1,3,4]]  #即可以自由选取行位置，和列位置对应的数据，切零散的数据块
# Out:
#    account_length phone_number intl_plan
# 0             128     382-4657        no
# 2             137     358-1921        no
# 3              84     375-9999       yes

# %%
data.loc[5,['state','area_code']] #返回第 5 行'state'、'area_code'列，这种用于选取行索引列索引已知
# Out:
# state         AL
# area_code    510
# Name: 5, dtype: object

# %%
data[data["intl_plan"] == "yes"].head() #使用一个条件对数据进行筛选
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 3    OH              84        408     375-9999       yes              no
# 4    OK              75        415     330-6626       yes              no
# 5    AL             118        510     391-8027       yes              no
# 7    MO             147        415     329-9001       yes              no
# 9    WV             141        415     330-8173       yes             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 7                      0              157.0               79
# 9                     37              258.6               84
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 3             50.90  ...               88              5.26
# ...

# %%
data[(data["intl_plan"] == "yes")&(data["total_day_minutes"] >= 200)].head() 
#多个条件筛选的时候每个条件都必须加括号，只能使用&、|
#判断值是否在某一个范围内进行筛选的时候需要使用DataFrame.isin()
# Out:
#    state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 3     OH              84        408     375-9999       yes              no
# 5     AL             118        510     391-8027       yes              no
# 9     WV             141        415     330-8173       yes             yes
# 38    AK             136        415     402-1381       yes             yes
# 66    WY              43        415     329-9847       yes              no
#
#     number_vmail_messages  total_day_minutes  total_day_calls  \
# 3                       0              299.4               71
# 5                       0              223.4               98
# 9                      37              258.6               84
# 38                     33              203.9              106
# 66                      0              251.5              105
#
#     total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 3              50.90  ...               88              5.26
# ...

# %% [markdown]
# 数据清理
# =========

# %%
data = pd.read_csv("Machine_Learning/ML501/week2/data/Orange_Telecom_Churn_Data.csv")
data.drop(['total_intl_charge', 'number_customer_service_calls', 'area_code'], axis=1, inplace=True) #删除列
data.head()
# Out:
#   state  account_length phone_number intl_plan voice_mail_plan  \
# 0    KS             128     382-4657        no             yes
# 1    OH             107     371-7191        no             yes
# 2    NJ             137     358-1921        no              no
# 3    OH              84     375-9999       yes              no
# 4    OK              75     330-6626       yes              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data = pd.read_csv("Machine_Learning/ML501/week2/data/Orange_Telecom_Churn_Data.csv")

# %%
data.isnull().head(1) #data.isna()
# Out:
#    state  account_length  area_code  phone_number  intl_plan  voice_mail_plan  \
# 0  False           False      False         False      False            False
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                  False              False            False
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             False  ...            False             False
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                False              False               False
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0               False             False              False
#
#    number_customer_service_calls  churned
# 0                          False    False
#
# [1 rows x 21 columns]

# %%
data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %% [markdown]
# 函数作用: 删除含有空值的行或列 (默认参数：删除行，只要有空值就会删除，不替换。)
#
# axis: 维度，axis=0表示index行，axis=1表示columns列，默认为0
#
# how: "all"表示这一行或列中的元素全部缺失（为nan）才删除这一行或列，"any"表示这一行或列中只要有元素缺失，就删除这一行或列
#
# thresh: 一行或一列中至少出现了thresh个才删除
#
# subset: 在某些列的子集中选择出现了缺失值的列删除，不在子集中的含有缺失值得列或行不会删除（有axis决定是行还是列）
#
# inplace: 刷选过缺失值得新数据是存为副本还是直接在原数据上进行修改。

# %%
data.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)

# %% [markdown]
# 函数作用：填充缺失值
#
# value:需要用什么值去填充缺失值
#
# axis:确定填充维度，从行开始或是从列开始
#
# method："ffill"用缺失值前面的一个值代替缺失值, 如果axis =1，那么就是横向的前面的值替换后面的缺失值, 如果axis=0，那么则是上面的值替换下面的缺失值。backfill/bfill，缺失值后面的一个值代替前面的缺失值。注意这个参数不能与value同时出现
#
# limit:确定填充的个数，如果limit=2，则只填充两个缺失值。

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                  [3, 4, np.nan, 1],
                 [np.nan, np.nan, np.nan, 5],
                [np.nan, 3, np.nan, 4]],
                 columns=list('ABCD'))
 
print(df)
print()
print("横向用缺失值前面的值替换缺失值")
print(df.fillna(axis=1,method='ffill'))
print()
print("纵向用缺失值上面的值替换缺失值")
print(df.fillna(axis=0,method='ffill'))
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5
# 3  NaN  3.0 NaN  4
#
# 横向用缺失值前面的值替换缺失值
#      A    B    C    D
# 0  NaN  2.0  2.0  0.0
# 1  3.0  4.0  4.0  1.0
# 2  NaN  NaN  NaN  5.0
# 3  NaN  3.0  3.0  4.0
#
# 纵向用缺失值上面的值替换缺失值
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  3.0  4.0 NaN  5
# 3  3.0  3.0 NaN  4

# %% [markdown]
# DataFrame.apply(func, axis=0, broadcast=False, raw=False, reduce=None, args=(), **kwds)
#
# func传入你想要对数据实施的函数，axis=0表示对行操作，axis=1表示对列操作

# %%
# df['size_num'] = df.apply(lambda x:int(x['size']), axis=1) 
#将size转化为int类型

# %% [markdown]
# 数据汇总
# =======

# %%
df_boys=pd.DataFrame({'id':['1','2','3'],'age':['23','25','18']})
df_girls=pd.DataFrame({'id':['1','2','3'],'age':['18','18','18']})
print(pd.merge(df_boys,df_girls,on='id',suffixes=['_boys','_girls'])) # df_boys.append(df_girls)
# Out:
#   id age_boys age_girls
# 0  1       23        18
# 1  2       25        18
# 2  3       18        18

# %%
df1=pd.DataFrame({'A1':['1','2','3'],'A2':['23','25','18']})
df2=pd.DataFrame({'A3':['1','2','3'],'A4':['18','18','18']})
pd.concat([df1, df2],axis=1) #将df2中的列添加到df1的尾部
# Out:
#   A1  A2 A3  A4
# 0  1  23  1  18
# 1  2  25  2  18
# 2  3  18  3  18

# %%
data.groupby("state")["total_day_charge"].mean().head(3)
# Out:
# state
# AK    30.763333
# AL    32.210887
# AR    29.782065
# Name: total_day_charge, dtype: float64

# %%
data.groupby("state")["intl_plan"].value_counts().head(6)
# Out:
# state  intl_plan
# AK     no            66
#        yes            6
# AL     no           115
#        yes            9
# AR     no            82
#        yes           10
# Name: intl_plan, dtype: int64

# %%
data.groupby("state")["intl_plan"].value_counts().unstack().head(4)
# Out:
# intl_plan   no  yes
# state
# AK          66    6
# AL         115    9
# AR          82   10
# AZ          83    6

# %%
data.groupby("state")["intl_plan"].value_counts().unstack().head(20).plot(kind='bar', figsize=(20, 4))

# %%
#data.groupby("state")["total_day_charge"].plot(kind='kde', legend=True, figsize=(20, 5))

# %% [markdown]
# ‘line’ : line plot (default) #折线图
#
# ‘bar’ : vertical bar plot #条形图
#
# ‘barh’ : horizontal bar plot #横向条形图
#
# ‘hist’ : histogram #柱状图
#
# ‘box’ : boxplot #箱线图
#
# ‘kde’ : Kernel Density Estimation plot #Kernel的密度估计图, 主要对柱状图添加Kernel概率密度线
#
# ‘density’ : same as‘kde’
#
# ‘area’ : area plot #不了解此图
#
# ‘pie’ : pie plot #饼图
#
# ‘scatter’ : scatter plot #散点图
#
# ‘hexbin’ : hexbin plot #不了解此图

# %% [markdown]
# 数据分析
# =======

# %%
data.describe()
# Out:
#        account_length    area_code  number_vmail_messages  total_day_minutes  \
# count      5000.00000  5000.000000            5000.000000        5000.000000
# mean        100.25860   436.911400               7.755200         180.288900
# std          39.69456    42.209182              13.546393          53.894699
# min           1.00000   408.000000               0.000000           0.000000
# 25%          73.00000   408.000000               0.000000         143.700000
# 50%         100.00000   415.000000               0.000000         180.100000
# 75%         127.00000   415.000000              17.000000         216.200000
# max         243.00000   510.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      5000.000000       5000.000000        5000.000000      5000.000000
# mean        100.029400         30.649668         200.636560       100.191000
# ...

# %%
data['intl_plan'].value_counts()  #统计某一列x中各个值出现的次数
# Out:
# no     4527
# yes     473
# Name: intl_plan, dtype: int64

# %%
data.sample(n=3) #简单的数据采样
# Out:
#      state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 3381    MN              79        510     420-6493        no              no
# 1690    PA             174        415     353-1352        no             yes
# 1089    DE              85        510     420-2796        no              no
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 3381                      0              121.3              112
# 1690                     15              221.8              143
# 1089                      0              211.5              100
#
#       total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 3381             20.62  ...              107             24.04
# 1690             37.71  ...              115             17.90
# 1089             35.96  ...               88             15.69
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 3381                123.1                 83                5.54
# ...

# %%
data["total_day_calls"].std() #计算列的标准差
# Out:
# 19.831197415138462

# %%
data["total_day_charge"].corr(data["total_day_minutes"]) #相关性分析, 相关系数在-1到1之间，接近1为正相关，接近-1为负相关，0为不相关
# data.corr()
# Out:
# 0.9999999509831988

# %%
data["total_day_charge"].cov(data["total_day_minutes"]) #计算两个字段间的协方差
# data.cov()
# Out:
# 493.78691169713943

# %%
data = pd.read_csv("Iris_Data.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
data.groupby("species")["petal_width"].mean()
# Out:
# species
# Iris-setosa        0.244
# Iris-versicolor    1.326
# Iris-virginica     2.026
# Name: petal_width, dtype: float64
